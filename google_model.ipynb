# %%
from dotenv import load_dotenv
from google import genai
from google.genai import types
import numpy as np
import os
import pandas as pd
from tqdm import tqdm
load_dotenv()

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
client = genai.Client(api_key=GOOGLE_API_KEY)
for m in client.models.list():
    if "embedContent" in m.supported_actions:
        print(f"Model: {m.name}")
# Out:
# Model: models/embedding-001
# Model: models/text-embedding-004
# Model: models/gemini-embedding-exp-03-07
# Model: models/gemini-embedding-exp

# %% [markdown]
# ### Texts

# %%
text = open("data/Psychology2e_WEB_pdfminer_trimmed.txt", "rb").readlines()

# %%
sub_heading = set()
is_heading = False
for line in text:
    if line == b"CHAPTER OUTLINE\r\n":
        is_heading = True
    elif line == b"\r\n":
        is_heading = False
    
    if is_heading and line != b"CHAPTER OUTLINE\r\n":
        sub_heading.add(line)

# %%
current_heading = b"Introduction to Psychology"
text_dictionary = {current_heading: b""}
for header in sub_heading:
    text_dictionary[header] = header

for line in text:
    if line not in sub_heading: 
        text_dictionary[current_heading] += line
    else: 
        current_heading = line

# %%
context_texts = list(text_dictionary.values())
encoded_texts = client.models.embed_content(
    model="models/text-embedding-004",
    contents=context_texts,
    config=types.EmbedContentConfig(task_type="semantic_similarity")
)

# %%
pandas_text = pd.DataFrame(text_dictionary.items())
encoded_values = pd.Series([e.values for e in encoded_texts.embeddings])
pandas_text = pd.concat([pandas_text, encoded_values], axis=1, ignore_index=True)
pandas_text.columns = ["heading", "text", "embedding"]
pandas_text
# Out:
#                                               heading  \
# 0                       b'Introduction to Psychology'
# 1                   b'2.2 Approaches to Research\r\n'
# 2       b'15.1 What Are Psychological Disorders?\r\n'
# 3                  b'11.9 Personality Assessment\r\n'
# 4   b'15.5 Obsessive-Compulsive and Related Disord...
# ..                                                ...
# 84                    b'8.3 Problems with Memory\r\n'
# 85               b'12.3 Attitudes and Persuasion\r\n'
# 86                   b'1.4 Careers in Psychology\r\n'
# 87           b'12.5 Prejudice and Discrimination\r\n'
# 88                          b'15.8 Schizophrenia\r\n'
#
#                                                  text  \
# 0   b'Introduction to Psychology\r\n\r\n1\r\n\r\nF...
# 1   b"2.2 Approaches to Research\r\nLEARNING OBJEC...
# 2   b"15.1 What Are Psychological Disorders?\r\nLE...
# 3   b'11.9 Personality Assessment\r\n\r\nThree mon...
# 4   b'15.5 Obsessive-Compulsive and Related Disord...
# ..                                                ...
# 84  b"8.3 Problems with Memory\r\nLEARNING OBJECTI...
# 85  b'12.3 Attitudes and Persuasion\r\nLEARNING OB...
# 86  b'1.4 Careers in Psychology\r\n\r\nINTRODUCTIO...
# 87  b'12.5 Prejudice and Discrimination\r\nLEARNIN...
# 88  b'15.8 Schizophrenia\r\nLEARNING OBJECTIVES\r\...
#
#                                             embedding
# 0   [-0.07546733, 0.041844938, -0.049030498, -0.00...
# 1   [-0.036459424, -0.009044605, -0.05252878, 0.05...
# 2   [0.000678227, 0.040446203, -0.07473351, -0.025...
# 3   [-0.0014185614, 0.015965123, -0.03640059, 0.00...
# 4   [-0.015047858, 0.027823124, -0.030617189, -0.0...
# ..                                                ...
# 84  [0.029385079, -0.0054541607, -0.061692953, -0....
# 85  [-0.01957869, 0.022944044, -0.047297202, 0.009...
# 86  [0.028797848, 0.00783937, -0.06044895, 0.02265...
# 87  [-0.018282274, -0.008219105, -0.020435264, 0.0...
# 88  [0.010480228, 0.03357588, -0.08474764, -0.0188...
#
# [89 rows x 3 columns]

# %% [markdown]
# ```python
# changed_text = [""]
# index = 0
# for line in tqdm(text):
#     if line == b"\r\n":
#         index += 1
#         changed_text.append("")
#     else:
#         changed_text[index] += line.decode("utf-8").strip() + " "
# test_changed = changed_text[0:200]
# ```

# %% [markdown]
# ### Queries

# %%
queries = pd.read_json("Data/queries.json")
queries
# Out:
#     query_id                                           question
# 0          1       What is the scientific method in psychology?
# 1          2              What are the basic parts of a neuron?
# 2          3                      What are the stages of sleep?
# 3          4                      What is operant conditioning?
# 4          5             What is problem-solving in psychology?
# 5          6               What are the three stages of memory?
# 6          7            What are the key components of emotion?
# 7          8  What are the major personality traits in the F...
# 8          9                         What is social psychology?
# 9         10        What is the sociocultural model in therapy?
# 10        11                 What is the history of psychology?
# 11        12          Who were Wilhelm Wundt and William James?
# 12        13               What is functionalism in psychology?
# 13        14      What are Freud's contributions to psychology?
# 14        15                       What are Gestalt principles?
# 15        16                    What is classical conditioning?
# 16        17   What are Skinner's contributions to behaviorism?
# 17        18               What is Maslow's hierarchy of needs?
# 18        19                   What is client-centered therapy?
# 19        20                      What is cognitive psychology?
# 20        21                  What is developmental psychology?
# 21        22                             What is biopsychology?
# 22        23  What are evolutionary psychologists interested...
# 23        24                  What is sensation and perception?
# 24        25  What is the difference between sensation and p...
# 25        26  What are Jean Piaget's theories of cognitive d...
# 26        27                         What is object permanence?
# 27        28  What is the role of neurotransmitters in psych...
# 28        29      What is the Big Five personality trait model?
# 29        30                  What are psychological disorders?
# 30        31                                 What is the DSM-5?
# 31        32  What is the importance of ethics in psychologi...
# 32        33    What is the cognitive revolution in psychology?
# 33        34                       What is feminist psychology?
# 34        35                  What is multicultural psychology?
# 35        36  What are the challenges of cross-cultural psyc...
# 36        37                      What is stress in psychology?
# 37        38   What are the stages of psychosexual development?
# 38        39  What is the importance of replication in psych...
# 39        40  What are different types of psychological ther...
# 40        41  What is the role of neurotransmitters in menta...
# 41        42  What are major themes in industrial-organizati...
# 42        43      What is the role of social norms in behavior?
# 43        44  What is the difference between prejudice and d...
# 44        45  What are key takeaways from the Brown v. Board...
# 45        46  What is the scientific process of hypothesis t...
# 46        47  What are applications of psychology in education?
# 47        48  What is the difference between mood disorders ...
# 48        49  What is the impact of cultural diversity on ps...
# 49        50  What is the role of critical thinking in psych...

# %%
context_queries = list(queries["question"])
encoded_queries = client.models.embed_content(
    model="models/text-embedding-004",
    contents=context_queries,
    config=types.EmbedContentConfig(task_type="semantic_similarity")
)

# %%
query_embedding = pd.Series([q.values for q in encoded_queries.embeddings], name="embedding")
query_dataset = pd.concat([queries, query_embedding], axis=1)
query_dataset
# Out:
#     query_id                                           question  \
# 0          1       What is the scientific method in psychology?
# 1          2              What are the basic parts of a neuron?
# 2          3                      What are the stages of sleep?
# 3          4                      What is operant conditioning?
# 4          5             What is problem-solving in psychology?
# 5          6               What are the three stages of memory?
# 6          7            What are the key components of emotion?
# 7          8  What are the major personality traits in the F...
# 8          9                         What is social psychology?
# 9         10        What is the sociocultural model in therapy?
# 10        11                 What is the history of psychology?
# 11        12          Who were Wilhelm Wundt and William James?
# 12        13               What is functionalism in psychology?
# 13        14      What are Freud's contributions to psychology?
# 14        15                       What are Gestalt principles?
# 15        16                    What is classical conditioning?
# 16        17   What are Skinner's contributions to behaviorism?
# 17        18               What is Maslow's hierarchy of needs?
# 18        19                   What is client-centered therapy?
# 19        20                      What is cognitive psychology?
# 20        21                  What is developmental psychology?
# 21        22                             What is biopsychology?
# 22        23  What are evolutionary psychologists interested...
# 23        24                  What is sensation and perception?
# 24        25  What is the difference between sensation and p...
# 25        26  What are Jean Piaget's theories of cognitive d...
# 26        27                         What is object permanence?
# 27        28  What is the role of neurotransmitters in psych...
# 28        29      What is the Big Five personality trait model?
# 29        30                  What are psychological disorders?
# 30        31                                 What is the DSM-5?
# 31        32  What is the importance of ethics in psychologi...
# 32        33    What is the cognitive revolution in psychology?
# 33        34                       What is feminist psychology?
# 34        35                  What is multicultural psychology?
# 35        36  What are the challenges of cross-cultural psyc...
# 36        37                      What is stress in psychology?
# 37        38   What are the stages of psychosexual development?
# 38        39  What is the importance of replication in psych...
# 39        40  What are different types of psychological ther...
# 40        41  What is the role of neurotransmitters in menta...
# 41        42  What are major themes in industrial-organizati...
# 42        43      What is the role of social norms in behavior?
# 43        44  What is the difference between prejudice and d...
# 44        45  What are key takeaways from the Brown v. Board...
# 45        46  What is the scientific process of hypothesis t...
# 46        47  What are applications of psychology in education?
# 47        48  What is the difference between mood disorders ...
# 48        49  What is the impact of cultural diversity on ps...
# 49        50  What is the role of critical thinking in psych...
#
#                                             embedding
# 0   [-0.04588239, -0.0069801663, -0.060324635, 0.0...
# 1   [-0.012382562, 0.0035106149, -0.06658548, -0.0...
# 2   [-0.009869246, 0.044050507, -0.07744952, 0.005...
# 3   [-0.0537858, 0.059052367, -0.010571696, 0.0234...
# 4   [-0.025538992, -0.010091021, -0.032606736, -0....
# 5   [-0.005208647, 0.023910541, -0.06945862, 0.007...
# 6   [0.02735984, 0.0073419423, -0.019886509, -0.03...
# 7   [-0.02642403, 0.04769592, -0.013481175, -0.013...
# 8   [-0.03505938, 0.045698382, -0.036667515, -0.00...
# 9   [-0.023964964, 0.02008327, -0.043191914, 8.846...
# 10  [-0.033823796, 0.02234537, -0.0502559, 0.03472...
# 11  [-0.029479742, 0.005067459, -0.04400524, 0.030...
# 12  [-0.032972895, 0.046511795, -0.06915983, 0.000...
# 13  [-0.04753088, 0.020161496, -0.04970346, 0.0181...
# 14  [0.0051677558, 0.018560791, -0.05047159, -0.02...
# 15  [-0.06875438, 0.009040068, -0.018372467, 0.001...
# 16  [-0.05830294, 0.02111203, -0.016840806, 0.0383...
# 17  [-0.0062880944, 0.048561808, -0.02511721, -0.0...
# 18  [-0.00971117, -0.0021699353, -0.010986709, 0.0...
# 19  [-0.03313257, 0.037800983, -0.09008608, -0.034...
# 20  [-0.04647714, 0.010631422, -0.09801259, 0.0285...
# 21  [-0.026631244, 0.059850946, -0.09419612, -0.02...
# 22  [-0.04905406, 0.040441677, -0.06823387, 0.0279...
# 23  [-0.020130657, 0.02684774, -0.076653145, -0.01...
# 24  [-0.011509685, 0.016943745, -0.08346805, 0.001...
# 25  [-0.059903435, -0.0017044429, -0.07945022, 0.0...
# 26  [-0.04837948, 0.032364406, -0.0017837954, 0.01...
# 27  [-0.0056293174, 0.014363827, -0.10382785, -0.0...
# 28  [-0.043992035, 0.047795802, 0.0069124084, -0.0...
# 29  [-0.019987445, -0.003994665, -0.08823531, -0.0...
# 30  [-0.0012732313, 0.041982524, -0.021262687, -0....
# 31  [-0.031415787, 0.02077365, -0.06311566, 0.0497...
# 32  [-0.057565108, 0.05451556, -0.04390083, 0.0112...
# 33  [-0.008196393, -0.0038000722, -0.053399116, 0....
# 34  [0.005235722, 0.030704487, -0.054931063, -0.00...
# 35  [-0.038162127, 0.006911035, -0.042179033, 0.00...
# 36  [-0.0010152886, -0.004654694, -0.05109576, 0.0...
# 37  [-0.024331322, 0.04277716, -0.10631146, -0.012...
# 38  [-0.04072511, 0.038161512, -0.05103209, 0.0411...
# 39  [-0.004069564, -0.02836887, -0.05954728, 0.008...
# 40  [0.032234494, 0.014417395, -0.08357344, -0.018...
# 41  [-0.061471637, 0.030400775, -0.018248484, -0.0...
# 42  [-0.017451504, 0.027904872, -0.033639293, 0.01...
# 43  [-0.0023263749, 0.015014104, -0.053970486, -0....
# 44  [-0.044473726, 0.037215084, -0.0045186593, 0.0...
# 45  [-0.03951192, 0.016889248, -0.07938687, 0.0117...
# 46  [-0.06812356, -0.011343162, -0.08424489, 0.024...
# 47  [0.026920693, -0.01641687, -0.077888116, -0.03...
# 48  [-0.014792637, -0.0022496763, -0.065480255, 0....
# 49  [-0.011149377, -0.00019013135, -0.087929256, -...

# %% [markdown]
# ### Query vs Embedding

# %%
query_data = np.array([np.array(q) for q in query_dataset["embedding"]])
text_data = np.array([np.array(t) for t in pandas_text["embedding"]])
similarity = np.dot(query_data, text_data.T)
similarity.shape
# Out:
# (50, 89)

# %%
import seaborn as sns
